# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/expanded_watch_history_2024_08_03.csv')

# %%
df.columns
# Out:
# Index(['video_url', 'video_title', 'length_seconds', 'keywords', 'thumbnail',
#        'view_count', 'category', 'upload_date', 'channel_id', 'channel_name',
#        'channel_url', 'watch_date'],
#       dtype='object')

# %%
df
# Out:
#                                          video_url  \
# 0      https://www.youtube.com/watch?v=spKRpwKNAsc
# 1      https://www.youtube.com/watch?v=kw4PEULnfBo
# 2      https://www.youtube.com/watch?v=UBhl66Apue8
# 3      https://www.youtube.com/watch?v=CdCvgb-10YA
# 4      https://www.youtube.com/watch?v=8GhFmQPZAlo
# ...                                            ...
# 36965  https://www.youtube.com/watch?v=3_jxsuVfc24
# 36966  https://www.youtube.com/watch?v=5jFIVxtiJpc
# 36967  https://www.youtube.com/watch?v=igT8XYYhkmo
# 36968  https://www.youtube.com/watch?v=_cvJ6tfNG28
# 36969  https://www.youtube.com/watch?v=PqAH6_iSKwE
#
#                                              video_title  length_seconds  \
# 0                      KT #674 - SAM TALLENT + ARI MATTI          7836.0
# 1      How To Clean Your Guts Every Day – Top Surgeon...          2184.0
# 2               Ari Matti -  First Kill Tony Appearances          1994.0
# ...
